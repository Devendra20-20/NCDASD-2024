# %% [markdown]
# # Machine Learning Statistics & Relevant Analysis Using Python

# %% [markdown]
# # Arthmetic  Mean $\bar X =\frac{\sum{x}}{N}$

# %% [markdown]
# The arthmatic mean of the numbers 8, 3 5, 12, and 10 is

# %% [markdown]
# # Median = $L_1 +\bigg( \frac{\frac{N}{2}-(\sum f)_f}{f_{median}}\bigg)$
# Source: https://www.w3resource.com/python-exercises/numpy/python-numpy-stat-exercise-7.php

# %% [markdown]
# # Mode = $L_1 + \bigg(\frac{\Delta_1}{\Delta_1+\Delta_2}\bigg)c$

# %% [markdown]
# # Standard Deviation $\sigma = \sqrt{\frac{\sum(X-\bar{X})^2}{N}}$

# %% [markdown]
# # Standard Error (S.E.) $= \frac{\sqrt{\sigma}}{N}$

# %%
import numpy as np
L=[8, 3, 5, 12, 10]
X=np.mean(L)
X
Y=np.median(L)
Z=np.std(L)
P=np.var(L)
X,Y,Z,P
# Out:
# (7.6, 8.0, 3.2619012860600183, 10.64)

# %% [markdown]
# # Machine Learning - Linear Regression

# %% [markdown]
# # How to make simple Scatter plot?
# ### 1) import packages such as import matplotlib.pyplot as plt
# ### 2) Make two  list of data
# List1=x=[...,....,..]
# List2=y=[...,....,..]
#
# ### 3) plt.scatter(List1, List2) or  plt.scatter(x, y)
# ### 4) plt.show()

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %% [markdown]
# # How to fit the line with erreo bar?
# ### 1) do: import packages such as import matplotlib.pyplot as plt
# ### 2) do:  from scipy import stats
# List1=x=[...,....,..]
# List2=y=[...,....,..]
#
# ### 3) slope, intercept, r, p, std_err = stats.linregress(x, y)
# plt.errorbar(x, y, yerr=std_err,
#             fmt='o',capsize=5)
# Here,
#
#
# Returns
# Linregress Result:
#
# The return value is an object with the following attributes:
#
# 1)slope: float
#
#             Slope of the regression line.
# 2)intercept: float
#
#             Intercept of the regression line.
# 3) r value: float
#
#             Correlation coefficient.
# 4) p value: float
# Two-sided p-value for a hypothesis test whose null hypothesis is that the slope is zero, using Wald Test with t-distribution of the test statistic.
# 5) stderr: float
#
# Standard error of the estimated slope (gradient), under the assumption of residual normality.
#
#
# References: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html

# %%
import matplotlib.pyplot as plt
from scipy import stats
fig,ax=plt.subplots(figsize=(5,5))
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)
plt.errorbar(x, y, yerr=std_err,
            fmt='o',capsize=5)



def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))
plt.plot(x,mymodel,c='r',linewidth=2)
plt.xlabel('x', fontsize=16)
plt.ylabel('y', fontsize=16)
plt.xticks (fontsize=20)
plt.yticks(fontsize=20)
plt.tick_params(axis='x',length=8,width=1)
plt.tick_params(axis='y',length=8,width=1)
plt.tick_params(direction='in')

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)
def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show() 

print(r,p,std_err)
# Out:
# -0.758591524376155 0.002646873922456106 0.453536157607742

# %% [markdown]
# # Machine Learning - Polynomial Regression

# %%
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

plt.scatter(x, y)
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 2))

myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
import numpy as np #https://github.com/numpy/numpy 
import matplotlib.pyplot as plt #https://github.com/matplotlib/matplotlib
import scipy.stats as st #https://github.com/scipy/scipy
import pandas as pd #https://github.com/pandas-dev/pandas

# %%
df = pd.read_csv('Data.csv')
df
# Out:
#      h   m      s         RA   d  m.1   s.1        DEC     F60    F100  \
# 0    4  40  20.32  70.084667  45   12  36.8  45.210222  4.9004  23.223
# 1    4  40  19.95  70.083125  45   11   9.7  45.186028  4.8348  22.769
# 2    4  40  22.20  70.092500  45    9  42.5  45.161806  5.0315  22.565
# 3    4  40  21.08  70.087833  45    8   3.5  45.134306  5.8450  22.914
# 4    4  40  23.71  70.098792  45    2  15.1  45.037528  4.9721  22.856
# ..  ..  ..    ...        ...  ..  ...   ...        ...     ...     ...
# 195  4  37  53.17  69.471542  45    1  52.4  45.031222  4.7870  23.138
# 196  4  37  53.24  69.471833  45    0  29.3  45.008139  4.7069  22.922
# 197  4  37  53.68  69.473667  44   59   2.2  44.983944  4.5735  22.614
# 198  4  37  56.37  69.484875  44   57  15.5  44.954306  4.6398  23.243
# 199  4  37  44.64  69.436000  45    0  36.4  45.010111  4.8512  23.385
#
#             Td             B             M
# 0    23.357923  8.397450e-16  2.624653e+28
# ...

# %%
import pandas as pd
from scipy.stats import skew

# Assuming df is your DataFrame
# First, convert all columns to numeric (coerce non-numeric values to NaN)
df = df.apply(pd.to_numeric, errors='coerce')

# Calculate skewness for each column
skewness = df.apply(skew, axis=0, raw=True)

print("Skewness of each column")
print(skewness)
# Out:
# Skewness of each column
# h            NaN
# m       0.166829
# s       0.029132
# RA     -0.039112
# d      -1.036131
# m.1     0.963510
# s.1     0.317402
# DEC     0.197839
# F60     0.854584
# F100    0.003865
# Td      1.716893
# B       2.166705
# M      -1.103310
# dtype: float64
# C:\ProgramData\anaconda3\lib\site-packages\pandas\core\apply.py:846: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   result = func(*args, **kwargs)

# %%
import pandas as pd
from scipy.stats import kurtosis
# Calculate kurtosis for each column
kurt = df.apply(kurtosis)

print("Kurtosis for each column:")
print(kurt)
# Out:
# Kurtosis for each column:
# h             NaN
# m       -0.686995
# s       -1.252727
# RA      -1.075028
# d       -0.926433
# m.1     -0.954984
# s.1     -1.075107
# DEC     -0.916748
# F60      2.553948
# F100    -1.251690
# Td       9.003899
# B       12.483975
# M        5.021798
# dtype: float64
# C:\ProgramData\anaconda3\lib\site-packages\pandas\core\apply.py:907: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   results[i] = self.f(v)

# %%
variance = df.var()

print("Variance for each column:")
print(variance)
# Out:
# Variance for each column:
# h       0.000000e+00
# m       5.744724e-01
# s       3.130686e+02
# RA      2.875686e-02
# d       1.980905e-01
# m.1     5.382882e+02
# s.1     2.968221e+02
# DEC     7.749837e-03
# F60     6.211171e-02
# F100    5.168070e-01
# Td      3.844535e-02
# B       1.909571e-33
# M       1.790582e+54
# dtype: float64

# %%
# Calculate mean for each column
mean = df.mean()

# Calculate absolute deviations and then calculate MAD for each column
mad = (df - mean).abs().mean()

print("Mean Absolute Deviation (MAD) for each column:")
print(mad)
# Out:
# Mean Absolute Deviation (MAD) for each column:
# h       0.000000e+00
# m       6.476000e-01
# s       1.536964e+01
# RA      1.459085e-01
# d       3.942000e-01
# m.1     2.028790e+01
# s.1     1.491707e+01
# DEC     7.499835e-02
# F60     1.974580e-01
# F100    6.249302e-01
# Td      1.387435e-01
# B       3.012168e-17
# M       9.746191e+26
# dtype: float64

# %%
# Calculate mean and standard deviation for each column
mean = df.mean()
std_dev = df.std()

# Calculate coefficient of variation (CV) for each column
cv = (std_dev / mean) * 100  # Multiply by 100 to express as a percentage

print("Coefficient of Variation (CV) for each column:")
print(cv)
# Out:
# Coefficient of Variation (CV) for each column:
# h         0.000000
# m         1.957489
# s        60.538621
# RA        0.242943
# d         0.995022
# m.1     118.282127
# s.1      65.755223
# DEC       0.195351
# F60       5.478147
# F100      3.245055
# Td        0.845118
# B         5.420765
# M         4.897239
# dtype: float64

# %%
import pandas as pd  
data = pd.DataFrame(df)
  
print(data.corr())
# Out:
#        h         m         s        RA         d       m.1       s.1  \
# h    NaN       NaN       NaN       NaN       NaN       NaN       NaN
# m    NaN  1.000000 -0.450367  0.921591  0.236554 -0.197050 -0.085679
# s    NaN -0.450367  1.000000 -0.068487  0.013431 -0.011000 -0.031769
# RA   NaN  0.921591 -0.068487  1.000000  0.270162 -0.224964 -0.109548
# d    NaN  0.236554  0.013431  0.270162  1.000000 -0.987290 -0.046297
# m.1  NaN -0.197050 -0.011000 -0.224964 -0.987290  1.000000  0.037833
# s.1  NaN -0.085679 -0.031769 -0.109548 -0.046297  0.037833  1.000000
# DEC  NaN  0.325763  0.017862  0.371769  0.716579 -0.596953 -0.013525
# F60  NaN  0.353650 -0.126797  0.340040  0.421895 -0.355385  0.005590
# F100 NaN  0.062486 -0.097759  0.027321  0.118348 -0.051863  0.083924
# Td   NaN  0.484812 -0.102181  0.497300  0.549973 -0.508443 -0.061981
# B    NaN  0.482844 -0.102871  0.494801  0.530993 -0.490317 -0.065404
# M    NaN -0.481445  0.102921 -0.493216 -0.565058  0.526070  0.056219
#
# ...

# %%
import seaborn as sns
from scipy.stats import norm
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot= True, cmap= 'coolwarm',fmt='0.2f', linewidth=0.1)
# plt.xlabel(fontsize = 16,fontweight = 'bold')
# plt.ylabel(fontsize = 16,fontweight = 'bold')
plt.yticks(color='k',fontsize=12,rotation=45, fontweight='bold')
plt.xticks(color='k',fontsize=12, rotation=45,fontweight='bold')
plt.tick_params(axis='x',length=8,width=2)
plt.tick_params(axis='y',length=8,width=2)
plt.savefig('Fig7.eps', bbox_inches='tight',dpi = 600)

# %% [markdown]
# https://ipython-books.github.io/93-fitting-a-function-to-data-with-nonlinear-least-squares/

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.curve_fit.html
